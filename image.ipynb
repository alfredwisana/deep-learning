# %%
import numpy as mp
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# !wget https://docs.opencv.org/4.x/lena.png
# Out:
# --2024-02-22 12:35:08--  https://docs.opencv.org/4.x/lena.png
# Resolving docs.opencv.org (docs.opencv.org)... 172.67.218.21, 104.21.24.86, 199.249.112.1, ...
# Connecting to docs.opencv.org (docs.opencv.org)|172.67.218.21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 620636 (606K) [image/png]
# Saving to: ‘lena.png’
#
# lena.png            100%[===================>] 606.09K  2.10MB/s    in 0.3s
#
# 2024-02-22 12:35:09 (2.10 MB/s) - ‘lena.png’ saved [620636/620636]

# %%
image = cv2.imread('lena.png')
plt.imshow(image)
plt.show()

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(rgb)
plt.show()

# %%
rgb
# Out:
# array([[[193, 111,  74],
#         [198, 116,  79],
#         [195, 113,  76],
#         ...,
#         [146,  78,  55],
#         [146,  78,  55],
#         [146,  78,  55]],
#
#        [[196, 114,  77],
#         [197, 115,  78],
#         [194, 112,  75],
#         ...,
#         [148,  80,  57],
#         [148,  80,  57],
#         [148,  80,  57]],
#
#        [[199, 115,  78],
#         [192, 107,  76],
#         [200, 117,  77],
#         ...,
#         [150,  80,  54],
#         [147,  80,  54],
#         [145,  79,  55]],
#
#        ...,
#
#        [[168,  88,  61],
#         [170,  90,  63],
#         [174,  95,  65],
#         ...,
#         [ 69,  39,  37],
#         [ 69,  38,  36],
#         [ 71,  40,  38]],
#
#        [[166,  86,  61],
#         [169,  89,  62],
#         [171,  91,  64],
#         ...,
#         [ 68,  38,  36],
#         [ 68,  38,  36],
#         [ 71,  41,  39]],
#
#        [[158,  81,  55],
#         [165,  88,  62],
#         [167,  90,  62],
# ...

# %%
rgb_clone = rgb.copy()
rgb_clone[10:,50:,0] = 0
rgb_clone[10:80:,1] = 0
plt.imshow(rgb_clone)

# %%
exp_image= rgb.copy()
exp_image=[128]

# %%
resize = cv2.resize(rgb, (1000,1000), interpolation=cv2.INTER_AREA)
print("Shape : ",resize.shape)
plt.imshow(resize)
plt.show()
# Out:
# Shape :  (1000, 1000, 3)

# %%
norm_rgb = rgb/255.0
print(norm_rgb)
# Out:
# [[[0.75686275 0.43529412 0.29019608]
#   [0.77647059 0.45490196 0.30980392]
#   [0.76470588 0.44313725 0.29803922]
#   ...
#   [0.57254902 0.30588235 0.21568627]
#   [0.57254902 0.30588235 0.21568627]
#   [0.57254902 0.30588235 0.21568627]]
#
#  [[0.76862745 0.44705882 0.30196078]
#   [0.77254902 0.45098039 0.30588235]
#   [0.76078431 0.43921569 0.29411765]
#   ...
#   [0.58039216 0.31372549 0.22352941]
#   [0.58039216 0.31372549 0.22352941]
#   [0.58039216 0.31372549 0.22352941]]
#
#  [[0.78039216 0.45098039 0.30588235]
#   [0.75294118 0.41960784 0.29803922]
#   [0.78431373 0.45882353 0.30196078]
#   ...
#   [0.58823529 0.31372549 0.21176471]
#   [0.57647059 0.31372549 0.21176471]
#   [0.56862745 0.30980392 0.21568627]]
#
#  ...
#
#  [[0.65882353 0.34509804 0.23921569]
#   [0.66666667 0.35294118 0.24705882]
#   [0.68235294 0.37254902 0.25490196]
#   ...
#   [0.27058824 0.15294118 0.14509804]
#   [0.27058824 0.14901961 0.14117647]
#   [0.27843137 0.15686275 0.14901961]]
#
# ...

# %%
plt.imshow(norm_rgb)

# %%
print(gray)
# Out:
# [[131 136 133 ...  96  96  96]
#  [134 135 132 ...  98  98  98]
#  [136 129 137 ...  98  97  96]
#  ...
#  [109 111 115 ...  48  47  49]
#  [107 110 112 ...  47  47  50]
#  [101 108 110 ...  47  50  55]]

# %% [markdown]
# Convulution

# %%
rotate = cv2.rotate(gray,cv2.ROTATE_90_CLOCKWISE)
plt.imshow(rotate, cmap='gray')

# %%
rgb_clone = gray.copy()
rgb_clone[10:,50:,0] = 0
rgb_clone[:,50:,1] = 0
rgb_clone[:,50:,2] = 0
plt.imshow(rgb_clone)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 rgb_clone = gray.copy()
# ----> 2 rgb_clone[10:,50:,0] = 0
#       3 rgb_clone[:,50:,1] = 0
#       4 rgb_clone[:,50:,2] = 0
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed
